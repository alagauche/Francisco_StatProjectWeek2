# %% [markdown]
# # Matplotlib Exercises
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Write imports -- What different command(s) do you use if you aren't using a jupyter notebook, if at all?**

# %%
import matplotlib.pyplot as plt
# Out:
# /Users/Natera/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:279: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure(figsize=(6,6)) 
rect = 0, 0, 1, 1
ax = fig.add_axes(rect, label='axes1', facecolor='b')
ax.plot(x, y, 'b')
ax.set_xlabel('other numbers')
ax.set_ylabel('some numbers')
ax.set_title('terrible graph')

plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure(figsize=(6,6)) 
rect1 = 0, 0, 1, 1
rect2 = 0.2, 0.5, 0.2, 0.2

ax1 = fig.add_axes(rect1, facecolor='b')
ax2 = fig.add_axes(rect2, facecolor='r')

plt.show()

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure(figsize=(6,6)) 
rect1 = 0, 0, 1, 1
rect2 = 0.2, 0.5, 0.2, 0.2

ax1 = fig.add_axes(rect1, facecolor='b')
ax2 = fig.add_axes(rect2, facecolor='r')
ax1.plot(x, z)
ax2.plot(x, y)
plt.show()

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig1 = plt.figure()
rect1 = 0, 0, 1, 1
rect2 = 0.2, 0.5, 0.4, 0.4

ax1 = fig.add_axes(rect1, facecolor='b')
ax2 = fig.add_axes(rect2, facecolor='r')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_ylim(30,50)
ax2.set_xlim(20,22)

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig1 = plt.figure()
rect1 = 0, 0, 1, 1
rect2 = 0.2, 0.5, 0.4, 0.4

ax1 = fig.add_axes(rect1, facecolor='b')
ax2 = fig.add_axes(rect2, facecolor='r')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_ylim(30,50)
ax2.set_xlim(20,22)

ax1.plot(x,z)
ax2.plot(x,y)

plt.show()
# Out:
# Text(89.6,0.5,'y')

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
plt.show()

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y, color='green', lw="2")
axes[1].plot(x,z, "r--")

plt.show()

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,axes = plt.subplots(nrows=1,ncols=2, figsize=(6,6))

axes[0].plot(x,y,color='red',lw="5")
axes[1].plot(x,z,color='blue',lw="3")

plt.show()

# %% [markdown]
# # Great Job!
